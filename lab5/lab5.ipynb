# %%
# !uname -a
# Out:
# Linux deedd418acba 5.15.109+ #1 SMP Fri Jun 9 10:57:30 UTC 2023 x86_64 x86_64 x86_64 GNU/Linux

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Импорт библиотек

# %%
import matplotlib.pyplot as plt
import numpy as np
import pytest
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Создание датасетов

# %%
# Датасет 1
xs1 = np.linspace(0, 10, 100)
ys1 = xs1 + np.random.random(100)*2 - 1

plt.scatter(xs1, ys1)
plt.title("Датасет 1")
plt.show()

# %%
# Датасет 2
xs2 = np.linspace(0, 10, 100)
ys2 = 1.1*xs2 + np.random.random(100)*4 - 2

plt.scatter(xs2, ys2)
plt.title("Датасет 2")
plt.show()

# %%
# Датасет 3
xs3 = np.linspace(0, 10, 100)
ys3 = 0.95*xs3 + np.random.random(100)*3 - 2

plt.scatter(xs3, ys3)
plt.title("Датасет 3")
plt.show()

# %%
# Датасет 4 (с шумами)
xs4 = np.linspace(0, 10, 100)
ys4 = xs4 + np.random.random(100)*2 - 1
ys4[25:42] *= 2

plt.scatter(xs4, ys4)
plt.title("Датасет 4 (с шумами)")
plt.show()

# %% [markdown]
# # Обучение модели линейной регрессии на одном из датасетов

# %%
X_train = xs1.reshape(-1, 1)
y_train = ys1

model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Анализ качества предсказания

# %%
# Функция для анализа качества предсказания и записи данных
def analyze_predictions(xs, ys, dataset_name, idx):
    y_pred = model.predict(xs.reshape(-1, 1))

    np.savetxt(f"ys_{idx}.csv", ys, delimiter=",")
    np.savetxt(f"y_pred_{idx}.csv", y_pred, delimiter=",")

    plt.scatter(xs, ys)
    plt.plot(xs.reshape(-1, 1), y_pred, color="red")
    plt.title(f"{dataset_name} Prediction")
    plt.show()

    print(f"MSE for {dataset_name}: %.2f" % mean_squared_error(ys, y_pred))
    print(f"R2 for {dataset_name}: %.2f" % r2_score(ys, y_pred))
    print(f"Coefficients for {dataset_name}: %.2f" % model.coef_)
    print()

# Анализ качества предсказания на всех датасетах
analyze_predictions(xs1, ys1, "Датасет 1", 1)
analyze_predictions(xs2, ys2, "Датасет 2", 2)
analyze_predictions(xs3, ys3, "Датасет 3", 3)
analyze_predictions(xs4, ys4, "Датасет 4 (с шумами)", 4)
# Out:
# MSE for Датасет 1: 0.31
# R2 for Датасет 1: 0.96
# Coefficients for Датасет 1: 0.95
# MSE for Датасет 2: 1.59
# R2 for Датасет 2: 0.86
# Coefficients for Датасет 2: 0.95
# MSE for Датасет 3: 1.67
# R2 for Датасет 3: 0.81
# Coefficients for Датасет 3: 0.95
# MSE for Датасет 4 (с шумами): 2.20
# R2 for Датасет 4 (с шумами): 0.77
# Coefficients for Датасет 4 (с шумами): 0.95

# %% [markdown]
# # Обнаружение проблемы на датасете 4 (с шумами)

# %%
# Анализ остатков модели на датасете 4
y_pred4 = model.predict(xs4.reshape(-1, 1))
residuals = ys4 - y_pred4.flatten()

plt.scatter(xs4, residuals)
plt.xlabel("Input")
plt.ylabel("Residuals")
plt.title("Residuals Plot (Dataset 4)")
plt.show()

# %% [markdown]
# **Судя по анализу остатков модели, то есть разницы между фактическими значениями и предсказанными значениями, остатки показывают некоторую структуру или паттерн, что может указывать на проблему в модели или неучтённые факторы в данных. Проведём тестирование данных.**

# %% [markdown]
# # Тестирование работы модели на всех 4 датасетах

# %%
# %%writefile test_score.py
import numpy as np
import pytest
from sklearn.metrics import mean_squared_error, r2_score


@pytest.fixture
def load_ys():
    ys = [np.loadtxt(f"ys_{idx}.csv", delimiter=",") for idx in range(1, 5)]
    return ys

@pytest.fixture
def load_y_pred():
    y_pred = [np.loadtxt(f"y_pred_{idx}.csv", delimiter=",") for idx in range(1, 5)]
    return(y_pred)

def test_mse(load_ys, load_y_pred):
    for idx, (ys, y_pred) in enumerate(zip(load_ys, load_y_pred), start=1):
        assert mean_squared_error(ys, y_pred) < 1, f"Test failed for file: ys_{idx}.csv"

def test_r2(load_ys, load_y_pred):
    for idx, (ys, y_pred) in enumerate(zip(load_ys, load_y_pred), start=1):
        assert r2_score(ys, y_pred) > 0.9, f"Test failed for file: ys_{idx}.csv"
# Out:
# Writing test_score.py

# %%
# !cat test_score.py
# Out:
# import numpy as np
# import pytest
# from sklearn.metrics import mean_squared_error, r2_score
#
#
# @pytest.fixture
# def load_ys():
#     ys = [np.loadtxt(f"ys_{idx}.csv", delimiter=",") for idx in range(1, 5)]
#     return ys
#
# @pytest.fixture
# def load_y_pred():
#     y_pred = [np.loadtxt(f"y_pred_{idx}.csv", delimiter=",") for idx in range(1, 5)]
#     return(y_pred)
#
# def test_mse(load_ys, load_y_pred):
#     for idx, (ys, y_pred) in enumerate(zip(load_ys, load_y_pred), start=1):
#         assert mean_squared_error(ys, y_pred) < 1, f"Test failed for file: ys_{idx}.csv"
#
# def test_r2(load_ys, load_y_pred):
#     for idx, (ys, y_pred) in enumerate(zip(load_ys, load_y_pred), start=1):
#         assert r2_score(ys, y_pred) > 0.9, f"Test failed for file: ys_{idx}.csv"

# %%
# !pytest -v test_score.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.10.12, pytest-7.4.1, pluggy-1.3.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content
# plugins: anyio-3.7.1
# collected 2 items
#
# test_score.py::test_mse FAILED                                           [ 50%]
# test_score.py::test_r2 FAILED                                            [100%]
#
# =================================== FAILURES ===================================
# ___________________________________ test_mse ___________________________________
#
# load_ys = [array([ 0.81013745,  0.51606735,  1.17451474,  1.07918972,  0.84414136,
#         1.0500413 ,  1.47354025,  1.59034458,...85275,  9.59117741,  8.58331396,  9.2882237 ,
#         8.73130004, 10.19220413,  9.14319679, 10.09508383,  9.21763607])]
# load_y_pred = [array([0.28992347, 0.38623428, 0.4825451 , 0.57885591, 0.67516672,
#        0.77147753, 0.86778834, 0.96409916, 1.06040...8, 9.05420739, 9.1505182 , 9.24682902, 9.34313983,
#        9.43945064, 9.53576145, 9.63207227, 9.72838308, 9.82469389])]
#
#     def test_mse(load_ys, load_y_pred):
#         for idx, (ys, y_pred) in enumerate(zip(load_ys, load_y_pred), start=1):
# >           assert mean_squared_error(ys, y_pred) < 1, f"Test failed for file: ys_{idx}.csv"
# E           AssertionError: Test failed for file: ys_2.csv
# E           assert 1.58733673351215 < 1
# E            +  where 1.58733673351215 = mean_squared_error(array([-1.28274268,  0.25505974,  1.35929662, -0.8590709 ,  1.37875528,\n        0.31954088,  0.01593169, -0.48698644,  0.89184974,  0.71927234,\n       -0.28156464, -0.32435132, -0.44553916,  2.95187124, -0.13733293,\n        2.76797118,  2.59013451,  0.53729849,  3.67499961,  3.59043922,\n        3.92648083,  3.03238879,  1.70113039,  2.32086988,  1.4120481 ,\n        4.46566866,  3.6453117 ,  1.41358995,  2.53028901,  1.84838502,\n        1.63784982,  1.75003161,  2.27652061,  2.0640419 ,  5.60806559,\n        3.13728696,  5.09645494,  2.92558574,  2.51117514,  3.93789485,\n        4.39192539,  6.36211873,  6.39871122,  3.46345506,  5.40919976,\n        5.75682987,  5.36696447,  6.69578806,  7.21132242,  5.21968887,\n        5.51187418,  6.32452265,  6.37484663,  7.20593385,  5.9686976 ,\n        6.96386663,  5.7359465 ,  4.74333505,  8.29378605,  6.91462007,\n        7.47550289,  6.60181366,  7.74563632,  5.17602634,  6.77479469,\n        8.23684879,  6.18467578,  7.46937052,  6.04597678,  6.21978404,\n        6.18755947,  8.17398133,  8.50155   ,  8.53912528,  8.87230707,\n        9.53529057,  9.24316558,  9.13692978, 10.04339908,  6.78282522,\n        9.05010656,  7.32932883,  7.1581326 , 10.40788291,  8.59062739,\n        8.71620035, 10.16622784,  9.9233889 ,  8.57248676,  9.36632222,\n        8.93982705, 10.66665357, 10.22629908,  9.35813157,  9.58205727,\n       10.4895854 , 10.74240902, 12.44559262, 10.27486827, 10.87643889]), array([0.28992347, 0.38623428, 0.4825451 , 0.57885591, 0.67516672,\n       0.77147753, 0.86778834, 0.96409916, 1.06040997, 1.15672078,\n       1.25303159, 1.34934241, 1.44565322, 1.54196403, 1.63827484,\n
692978, 10.04339908,  6.78282522,\n        9.05010656,  7.32932883,  7.1581326 , 10.40788291,  8.59062739,\n        8.71620035, 10.16622784,  9.9233889 ,  8.57248676,  9.36632222,\n        8.93982705, 10.66665357, 10.22629908,  9.35813157,  9.58205727,\n       10.4895854 , 10.74240902, 12.44559262, 10.27486827, 10.87643889]), array([0.28992347, 0.38623428, 0.4825451 , 0.57885591, 0.67516672,\n       0.77147753, 0.86778834, 0.96409916, 1.06040997, 1.15672078,\n       1.25303159, 1.34934241, 1.44565322, 1.54196403, 1.63827484,\n       1.73458566, 1.83089647, 1.92720728, 2.02351809, 2.1198289 ,\n       2.21613972, 2.31245053, 2.40876134, 2.50507215, 2.60138297,\n       2.69769378, 2.79400459, 2.8903154 , 2.98662622, 3.08293703,\n       3.17924784, 3.27555865, 3.37186946, 3.46818028, 3.56449109,\n       3.6608019 , 3.75711271, 3.85342353, 3.94973434, 4.04604515,\n       4.14235596, 4.23866678, 4.33497759, 4.4312884 , 4.52759921,\n       4.62391002, 4.72022084, 4.81653165, 4.91284246, 5.00915327,\n       5.10546409, 5.2017749 , 5.29808571, 5.39439652, 5.49070734,\n       5.58701815, 5.68332896, 5.77963977, 5.87595058, 5.9722614 ,\n       6.06857221, 6.16488302, 6.26119383, 6.35750465, 6.45381546,\n       6.55012627, 6.64643708, 6.7427479 , 6.83905871, 6.93536952,\n       7.03168033, 7.12799114, 7.22430196, 7.32061277, 7.41692358,\n       7.51323439, 7.60954521, 7.70585602, 7.80216683, 7.89847764,\n       7.99478846, 8.09109927, 8.18741008, 8.28372089, 8.3800317 ,\n       8.47634252, 8.57265333, 8.66896414, 8.76527495, 8.86158577,\n       8.95789658, 9.05420739, 9.1505182 , 9.24682902, 9.34313983,\n       9.43945064, 9.53576145, 9.63207227, 9.72838308, 9.82469389]))
#
# test_score.py:22: AssertionError
# =========================== short test summary info ============================
# FAILED test_score.py::test_mse - AssertionError: Test failed for file: ys_2.csv
# FAILED test_score.py::test_r2 - AssertionError: Test failed for file: ys_2.csv
# ============================== 2 failed in 1.17s ===============================

# %% [markdown]
# # Юнит-тест

# %%
# !mkdir test_module

# %%
# %%writefile test_module/test_unit.py
import numpy as np
import unittest
from sklearn.metrics import mean_squared_error, r2_score


class TestMethods(unittest.TestCase):

    def test_mse(self):
        load_ys = [np.loadtxt(f"ys_{idx}.csv", delimiter=",") for idx in range(1, 5)]
        load_y_pred = [np.loadtxt(f"y_pred_{idx}.csv", delimiter=",") for idx in range(1, 5)]

        for idx, (ys, y_pred) in enumerate(zip(load_ys, load_y_pred), start=1):
            self.assertLess(mean_squared_error(ys, y_pred), 1, f"Test failed for dataset {idx}")

    def test_r2(self):
        load_ys = [np.loadtxt(f"ys_{idx}.csv", delimiter=",") for idx in range(1, 5)]
        load_y_pred = [np.loadtxt(f"y_pred_{idx}.csv", delimiter=",") for idx in range(1, 5)]

        for idx, (ys, y_pred) in enumerate(zip(load_ys, load_y_pred), start=1):
            self.assertGreater(r2_score(ys, y_pred), 0.9, f"Test failed for dataset {idx}")

if __name__ == '__main__':
    unittest.main()
# Out:
# Writing test_module/test_unit.py

# %%
# !python -m unittest test_module/test_unit.py
# Out:
# FF
# ======================================================================
# FAIL: test_mse (test_module.test_unit.TestMethods)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/content/test_module/test_unit.py", line 13, in test_mse
#     self.assertLess(mean_squared_error(ys, y_pred), 1, f"Test failed for dataset {idx}")
# AssertionError: 1.58733673351215 not less than 1 : Test failed for dataset 2
#
# ======================================================================
# FAIL: test_r2 (test_module.test_unit.TestMethods)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/content/test_module/test_unit.py", line 20, in test_r2
#     self.assertGreater(r2_score(ys, y_pred), 0.9, f"Test failed for dataset {idx}")
# AssertionError: 0.8643324050890531 not greater than 0.9 : Test failed for dataset 2
#
# ----------------------------------------------------------------------
# Ran 2 tests in 0.009s
#
# FAILED (failures=2)
